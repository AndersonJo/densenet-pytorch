# %%
# %pylab inline

import numpy as np

from torchvision.datasets import CIFAR10
from torchvision import transforms
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Data

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train = CIFAR10('./CIFAR10', train=True,  transform=transform, download=True)
test  = CIFAR10('./CIFAR10', train=False, transform=transform, download=True)

train_x = train.train_data
train_y = np.array(train.train_labels)
test_x = test.test_data
test_y = np.array(test.test_labels)

print('train_x:', train_x.shape)
print('train_y:', train_y.shape)
print('test_x:', test_x.shape)
print('test_y:', test_y.shape)
# Out:
# ...
# Files already downloaded and verified
# train_x: (50000, 32, 32, 3)
# train_y: (50000,)
# test_x: (10000, 32, 32, 3)
# test_y: (10000,)

# %%
fig, subplots = pylab.subplots(10, 14, figsize=(12, 8)) # subplots(y축, x축 갯수)
subplots = subplots.T.reshape(-1)

for i, p in enumerate(subplots):
    target = test_x[test_y == i%10]
    idx = np.random.randint(target.shape[0])
    d = target[idx]
    p.get_xaxis().set_visible(False)
    p.get_yaxis().set_visible(False)
    p.imshow(d)
